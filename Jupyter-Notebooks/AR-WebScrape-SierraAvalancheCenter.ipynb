# %% [markdown]
# ## Web Scraper to scrape data from Sierra Avalanche Center
# (and potentially other avalanche centers in USA)
#
#
# * Observations can be searched on the website
# * The search results are resulted as Json data to the browser
# * The resulted Json data has most of the information which can be used to download the images and store the meta information about them
#
#
# ### Web Scraping Process:
#
# * We will first manually go to Avalanche Center website and search for observations (it is important to not pull too much data in one go (due to Json return size limit). So we will limit to search 3 months at a time
#
# * The resultes json data will be stored in our S3 bucket s3://s3-avalanche-guard/data/avalanche_center/webscrape/SAC/json/unprocessed
#
# * We will run a Python script to download the images in the Json and flatten their meta data. After processing the original json file will be moved to s3://s3-avalanche-guard/data/avalanche_center/webscrape/SAC/json/processed
#
# >* The downloaded image files will be kept at s3://s3-avalanche-guard/data/avalanche_center/webscrape/images
#
# >* The corresponding meta data for each image will be kept at s3://s3-avalanche-guard/data/avalanche_center/webscrape/images-metadata
#
#
#
#
#
# To access S3 or any other AWS services we need SDK
# The SDK is composed of two key Python packages: Botocore (the library providing the low-level functionality shared between the Python SDK and the AWS CLI) and Boto3 (the package implementing the Python SDK itself).

# %%
import boto3
import random
import shutil
import json
from io import BytesIO, StringIO
import pandas as pd

# %%
# move an S3 object to another object
# example:
#move_s3_object('my_bucket', old_key='tmp/test.txt', new_key='tmp/tmp2/test.txt')
def move_s3_object(bucket: str, old_key: str, new_key: str) -> None:
    boto3.resource('s3').Object(bucket,  new_key).copy_from(CopySource=f'{bucket}/{old_key}')
    boto3.client('s3').delete_object(Bucket=bucket, Key=old_key)

# move an S3 object to another folder
# example:
#move_s3_object('my_bucket', old_folder='tmp/', new_folder='tmp/tmp2/', object_name='test.txt')
def s3_move_to_another_folder(bucket: str, old_folder: str, new_folder: str, object_name:str) -> None:
    
    old_key = old_folder+object_name
    new_key = new_folder+object_name
    boto3.resource('s3').Object(bucket,  new_key).copy_from(CopySource=f'{bucket}/{old_key}')
    boto3.client('s3').delete_object(Bucket=bucket, Key=old_key)

    

#print bucket contents
def print_all_s3_objects(bucket_name:str, prefix:str):
    s3 = boto3.client('s3')
    paginator = s3.get_paginator('list_objects_v2')
    page_iterator = paginator.paginate(Bucket=bucket_name,Prefix=prefix)

    for page in page_iterator:
        if 'Contents' in page:
            for obj in page['Contents']:
                print(f'Name: {obj["Key"]} | Size: {obj["Size"]}')
        else:
            print("Bucket is empty or does not exist")


# Get bucket contents as a list
def list_all_s3_objects(bucket_name:str, prefix:str)-> [str]:
    s3 = boto3.client('s3')
    paginator = s3.get_paginator('list_objects_v2')
    page_iterator = paginator.paginate(Bucket=bucket_name,Prefix=prefix)

    objlist = []
    for page in page_iterator:
        if 'Contents' in page:
            for obj in page['Contents']:
                if obj["Key"].replace(prefix, "") != "":
                    objlist.append( obj["Key"].replace(prefix, ""))

    return objlist
            

    
# send an url based image to s3
def send_image_to_s3(url, foldername, filename, bucket_name ):
    print(f"sending image {url}")
    ##bucket_name = 'XXX'
    ##AWS_SECRET_ACCESS_KEY = "XXX"
    ##AWS_ACCESS_KEY_ID = "XXX"

    s3 = boto3.client('s3') ##, aws_access_key_id=AWS_ACCESS_KEY_ID,         aws_secret_access_key=AWS_SECRET_ACCESS_KEY)

    response = requests.get(url)
    img = BytesIO(response.content)

    file_name = f'{foldername}/{filename}'
    print('sending {}'.format(file_name))
    r = s3.upload_fileobj(img, bucket_name, file_name)

    s3_path = file_name
    return s3_path    
    
###################################################################

# process manually downloaded Json data from Avalanche Center
# Download the image and save meta data based on the Json
def process_json_download():
    S3_BUCKET_NAME = "s3-avalanche-guard"
    UNPROC_JSON_FOLDER = "data/avalanche_center/webscrape/SAC/json/unprocessed/"
    PROC_JSON_FOLDER = "data/avalanche_center/webscrape/SAC/json/processed/"
    IMAGE_UPLOAD_FOLDER = "data/avalanche_center/webscrape/Images"
    CSV_UPLOAD_FOLDER = "data/avalanche_center/webscrape/Images-metadata"
    
    
    
    
    
    s3 = boto3.resource('s3')
    jsonfilelist = list_all_s3_objects(S3_BUCKET_NAME,UNPROC_JSON_FOLDER)
    for jsonfile in jsonfilelist:
        print(jsonfile)
    
        content_object = s3.Object(S3_BUCKET_NAME, UNPROC_JSON_FOLDER+jsonfile)
        file_content = content_object.get()['Body'].read().decode('utf-8')
        #print(str(file_content)[:100])
        #print(str(file_content)[len(str(file_content))-10:])
        #json_content = json.loads(repr(file_content))
        json_content = json.loads(str(file_content))
        
        proc_avalanche_center_json(jsonfile, json_content,S3_BUCKET_NAME, IMAGE_UPLOAD_FOLDER,CSV_UPLOAD_FOLDER )
        s3_move_to_another_folder(S3_BUCKET_NAME, UNPROC_JSON_FOLDER, PROC_JSON_FOLDER, jsonfile) 
    
        
    return None

# process given Json content of Avalanche Center data
def proc_avalanche_center_json(jsonfile, jsondata, bucket_name, folder_name, csv_folder_name):
    print(str(jsondata)[:100])
    observation_list = jsondata["data"]["getObservationList"]
    print(len(observation_list))

    #create a dictionary structure for storing meta data
    obs_dict = {}
    obs_dict_list = []
    MAX_COUNT = 10000
    
    i = 0
    for obs in observation_list:
        i = i + 1
        if i> MAX_COUNT:
            break
            
        #print(f"Observation = {obs}")
        for media in obs["media"]:
            #print(f"Media = {media}")
            print(f'MediaType = {media["type"]}')
            if media["type"] != "image":
                print(f'Skipping MediaType = {media["type"]}')
                pass
            #print(f"Media = {media}")
            media_seq = media["id"]
            media_seq_s = str(media_seq)
            media_id = obs["id"] + "-"+media_seq_s
            obs_dict = dict( Media_id = media_id,
                             Media_type =  media["type"],
                             ObservationId = obs["id"],
                             Obs_startDate = obs["startDate"],
                             Obs_createdAt = obs["createdAt"],
                             Obs_source = obs["obsSource"],
                             Obs_loc_lat = obs["locationPoint"]["lat"],
                             Obs_loc_lng = obs["locationPoint"]["lng"],
                             Obs_loc_Name = obs["locationName"],
                             Obs_submitterName = obs["name"],
                             Obs_route = obs["route"],
                             Obs_private = obs["private"],
                             Instability_cracking = obs["instability"]["cracking"],
                             Instability_collapsing = obs["instability"]["collapsing"],
                             Avalanches_caught = obs["instability"]["avalanches_caught"],
                             Avalanches_observed = obs["instability"]["avalanches_observed"],
                             Avalanches_triggered = obs["instability"]["avalanches_triggered"],
                             Cracking_description = obs["instability"]["cracking_description"],
                             Collapsing_description = obs["instability"]["collapsing_description"],
                             ObserverType = obs["observerType"],
                             Organization = obs["organization"],
                             Obs_status = obs["status"],
                             Media_Title = media["title"],
                             Media_Caption = media["caption"],
                             Media_Orig_Url = media["url"]["original"]
                        )
            print("***************************************************")
            print(f"Media Id = {media_id}")
            #print(obs_dict)
            obs_dict_list.append(obs_dict)
            send_image_to_s3(obs_dict["Media_Orig_Url"], folder_name, media_id+".jpg" , bucket_name)
    
    df = pd.DataFrame(obs_dict_list)
    
    csv_buffer = StringIO()
    df.to_csv(csv_buffer)
    s3_resource = boto3.resource('s3')
    csv_file_name = f"{csv_folder_name}/{jsonfile}.csv"
    s3_resource.Object(bucket_name, csv_file_name).put(Body=csv_buffer.getvalue())
            
    

###########################################################################################

# %% [markdown]
# ### Now Process

# %%
##print_all_s3_objects(s3_bucket_name,"data/cv/uibk/ResNetClassify/train/negative/")

SKIP = False
print(SKIP)
if SKIP :
    print('Skipping the Process entirely')
    pass
else:
    process_json_download()
# Out:
# False
# SAC_240124_TO_240331.json
# {'data': {'getObservationList': [{'id': '035e6998-f107-4d3b-a19d-5300a1ce5623', 'startDate': '2024-0
# 313
# MediaType = image
# ***************************************************
# Media Id = 035e6998-f107-4d3b-a19d-5300a1ce5623-66ce6700-c387-11ee-8959-23bb16b7c4e3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_0683_65bfd0ee25aa2.jpeg
# sending data/avalanche_center/webscrape/Images/035e6998-f107-4d3b-a19d-5300a1ce5623-66ce6700-c387-11ee-8959-23bb16b7c4e3.jpg
# MediaType = image
# ***************************************************
# Media Id = 035e6998-f107-4d3b-a19d-5300a1ce5623-67242d16-c387-11ee-a429-834da70d4466
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_0673_65bfd0ee4c58d.jpeg
# sending data/avalanche_center/webscrape/Images/035e6998-f107-4d3b-a19d-5300a1ce5623-67242d16-c387-11ee-a429-834da70d4466.jpg
# MediaType = image
# ***************************************************
# Media Id = fbfbc17a-753d-4936-b127-999aead0f551-403c77f2-bcd0-11ee-8baf-c3acefb87f44
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_7082_65b48cad4b1ff.JPG
# sending data/avalanche_center/webscrape/Images/fbfbc17a-753d-4936-b127-999aead0f551-403c77f2-bcd0-11ee-8baf-c3acefb87f44.jpg
# MediaType = image
# ***************************************************
# Media Id = bb4017ea-7c49-403b-9bfa-3a9e1705e637-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240206_185055263~2_65c2b5db22760.jpg
# sending data/avalanche_center/webscrape/Images/bb4017ea-7c49-403b-9bfa-3a9e1705e637-1.jpg
# MediaType = image
# ***************************************************
# Media Id = bb4017ea-7c49-403b-9bfa-3a9e1705e637-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240206_192730690_65c2b5d181905.PANO_65c2b5d181905.jpg
# sending data/avalanche_center/webscrape/Images/bb4017ea-7c49-403b-9bfa-3a9e1705e637-2.jpg
# MediaType = image
# ***************************************************
# Media Id = bb4017ea-7c49-403b-9bfa-3a9e1705e637-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240206_183642838_65c2b5d448018.jpg
# sending data/avalanche_center/webscrape/Images/bb4017ea-7c49-403b-9bfa-3a9e1705e637-3.jpg
# MediaType = image
# ***************************************************
# Media Id = bb4017ea-7c49-403b-9bfa-3a9e1705e637-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/cornices_65c2b5db9da6a.jpg
# sending data/avalanche_center/webscrape/Images/bb4017ea-7c49-403b-9bfa-3a9e1705e637-4.jpg
# MediaType = image
# ***************************************************
# Media Id = bb4017ea-7c49-403b-9bfa-3a9e1705e637-5
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/rime_65c2b5d75b056.jpg
# sending data/avalanche_center/webscrape/Images/bb4017ea-7c49-403b-9bfa-3a9e1705e637-5.jpg
# MediaType = image
# ***************************************************
# Media Id = bb4017ea-7c49-403b-9bfa-3a9e1705e637-6
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240206_195803223_65c2b5d7816ec.jpg
# sending data/avalanche_center/webscrape/Images/bb4017ea-7c49-403b-9bfa-3a9e1705e637-6.jpg
# MediaType = image
# ***************************************************
# Media Id = 736d6e59-4046-49ce-92e9-af27e350729d-88fe183e-c3b4-11ee-9b75-fbb9891e0fcd
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_0743_65c01ca6bcfe4.JPG
# sending data/avalanche_center/webscrape/Images/736d6e59-4046-49ce-92e9-af27e350729d-88fe183e-c3b4-11ee-9b75-fbb9891e0fcd.jpg
# MediaType = image
# ***************************************************
# Media Id = 736d6e59-4046-49ce-92e9-af27e350729d-89356000-c3b4-11ee-bf4f-db495b3989bf
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_0738_65c01ca6c16a5.JPG
# sending data/avalanche_center/webscrape/Images/736d6e59-4046-49ce-92e9-af27e350729d-89356000-c3b4-11ee-bf4f-db495b3989bf.jpg
# MediaType = image
# ***************************************************
# Media Id = 037e4655-eae6-4e93-a6d7-96f39c1df926-067ec026-c94e-11ee-b58b-2f1e6acd992c
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/WetLooseSlideMountain_pub_65c981a7190b9.jpg
# sending data/avalanche_center/webscrape/Images/037e4655-eae6-4e93-a6d7-96f39c1df926-067ec026-c94e-11ee-b58b-2f1e6acd992c.jpg
# MediaType = image
# ***************************************************
# Media Id = 6fbb196b-3f25-43eb-a2cb-a6a18bbb9119-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_2453_65b57371c5928.jpg
# sending data/avalanche_center/webscrape/Images/6fbb196b-3f25-43eb-a2cb-a6a18bbb9119-1.jpg
# MediaType = image
# ***************************************************
# Media Id = 6fbb196b-3f25-43eb-a2cb-a6a18bbb9119-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240127_181813226_65b5723fc4d05.MP_65b5723fc4d05.jpg
# sending data/avalanche_center/webscrape/Images/6fbb196b-3f25-43eb-a2cb-a6a18bbb9119-2.jpg
# MediaType = image
# ***************************************************
# Media Id = 6fbb196b-3f25-43eb-a2cb-a6a18bbb9119-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240127_192249685_65b572407ae98.MP_65b572407ae98.jpg
# sending data/avalanche_center/webscrape/Images/6fbb196b-3f25-43eb-a2cb-a6a18bbb9119-3.jpg
# MediaType = image
# ***************************************************
# Media Id = 6fbb196b-3f25-43eb-a2cb-a6a18bbb9119-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240127_183440484_65b5723ed0e64.MP_65b5723ed0e64.jpg
# sending data/avalanche_center/webscrape/Images/6fbb196b-3f25-43eb-a2cb-a6a18bbb9119-4.jpg
# MediaType = image
# ***************************************************
# Media Id = b03aee20-3160-49cb-aebd-d353ebc6827c-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000012520_66009c5128115.jpg
# sending data/avalanche_center/webscrape/Images/b03aee20-3160-49cb-aebd-d353ebc6827c-1.jpg
# MediaType = image
# ***************************************************
# Media Id = b03aee20-3160-49cb-aebd-d353ebc6827c-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000012501_66009c4dc1f7f.jpg
# sending data/avalanche_center/webscrape/Images/b03aee20-3160-49cb-aebd-d353ebc6827c-2.jpg
# MediaType = image
# ***************************************************
# Media Id = b03aee20-3160-49cb-aebd-d353ebc6827c-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000012521_66009c46052a5.jpg
# sending data/avalanche_center/webscrape/Images/b03aee20-3160-49cb-aebd-d353ebc6827c-3.jpg
# MediaType = image
# ***************************************************
# Media Id = a089e888-4e7a-4379-af79-e216b165f585-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1638_6605f46ce4ad4.jpeg
# sending data/avalanche_center/webscrape/Images/a089e888-4e7a-4379-af79-e216b165f585-1.jpg
# MediaType = image
# ***************************************************
# Media Id = a089e888-4e7a-4379-af79-e216b165f585-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1651_6605f46ee0f1c.jpeg
# sending data/avalanche_center/webscrape/Images/a089e888-4e7a-4379-af79-e216b165f585-2.jpg
# MediaType = image
# ***************************************************
# Media Id = a089e888-4e7a-4379-af79-e216b165f585-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1660_6605f46d426a1.jpeg
# sending data/avalanche_center/webscrape/Images/a089e888-4e7a-4379-af79-e216b165f585-3.jpg
# MediaType = image
# ***************************************************
# Media Id = a089e888-4e7a-4379-af79-e216b165f585-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1656_6605f46d042cc.jpeg
# sending data/avalanche_center/webscrape/Images/a089e888-4e7a-4379-af79-e216b165f585-4.jpg
# MediaType = image
# ***************************************************
# Media Id = a089e888-4e7a-4379-af79-e216b165f585-5
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1646_6605f46e1dc58.jpeg
# sending data/avalanche_center/webscrape/Images/a089e888-4e7a-4379-af79-e216b165f585-5.jpg
# MediaType = image
# ***************************************************
# Media Id = a089e888-4e7a-4379-af79-e216b165f585-6
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1661_6605f474c880f.jpeg
# sending data/avalanche_center/webscrape/Images/a089e888-4e7a-4379-af79-e216b165f585-6.jpg
# MediaType = image
# ***************************************************
# Media Id = a089e888-4e7a-4379-af79-e216b165f585-7
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1665_6605f476a1557.jpeg
# sending data/avalanche_center/webscrape/Images/a089e888-4e7a-4379-af79-e216b165f585-7.jpg
# MediaType = image
# ***************************************************
# Media Id = 6ec0b30f-9652-49a2-ae95-fd54e838fc9f-1cb21592-bd77-11ee-be3b-bb8584a9e0fc
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_4358_65b5a49f9ebde.jpg
# sending data/avalanche_center/webscrape/Images/6ec0b30f-9652-49a2-ae95-fd54e838fc9f-1cb21592-bd77-11ee-be3b-bb8584a9e0fc.jpg
# MediaType = image
# ***************************************************
# Media Id = 86193cc2-f249-4923-b594-e71e4db022e2-c8498c60-c5ff-11ee-8cf7-070ee92cf5da
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_0463_65c3f5e3ec766.jpeg
# sending data/avalanche_center/webscrape/Images/86193cc2-f249-4923-b594-e71e4db022e2-c8498c60-c5ff-11ee-8cf7-070ee92cf5da.jpg
# MediaType = image
# ***************************************************
# Media Id = 86193cc2-f249-4923-b594-e71e4db022e2-c8b2e318-c5ff-11ee-91b1-9b48aba80bce
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_0466_65c3f5e448044.jpeg
# sending data/avalanche_center/webscrape/Images/86193cc2-f249-4923-b594-e71e4db022e2-c8b2e318-c5ff-11ee-91b1-9b48aba80bce.jpg
# MediaType = image
# ***************************************************
# Media Id = 8cd901d9-1156-4e39-bc06-31533a88f7aa-f2443d6a-c642-11ee-b8bb-1fd9d97cbb87
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_9333_65c4669444a90.jpg
# sending data/avalanche_center/webscrape/Images/8cd901d9-1156-4e39-bc06-31533a88f7aa-f2443d6a-c642-11ee-b8bb-1fd9d97cbb87.jpg
# MediaType = image
# ***************************************************
# Media Id = 0808e795-2ec1-4d0d-aaf7-d1164db0c476-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000012659_6605f6901ffab.jpg
# sending data/avalanche_center/webscrape/Images/0808e795-2ec1-4d0d-aaf7-d1164db0c476-1.jpg
# MediaType = image
# ***************************************************
# Media Id = 0808e795-2ec1-4d0d-aaf7-d1164db0c476-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000012646_6605f68930bb6.jpg
# sending data/avalanche_center/webscrape/Images/0808e795-2ec1-4d0d-aaf7-d1164db0c476-2.jpg
# MediaType = image
# ***************************************************
# Media Id = 0808e795-2ec1-4d0d-aaf7-d1164db0c476-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000012657_6605f68f4e46b.jpg
# sending data/avalanche_center/webscrape/Images/0808e795-2ec1-4d0d-aaf7-d1164db0c476-3.jpg
# MediaType = image
# ***************************************************
# Media Id = 0808e795-2ec1-4d0d-aaf7-d1164db0c476-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000012653_6605f685abb16.jpg
# sending data/avalanche_center/webscrape/Images/0808e795-2ec1-4d0d-aaf7-d1164db0c476-4.jpg
# MediaType = image
# ***************************************************
# Media Id = 0808e795-2ec1-4d0d-aaf7-d1164db0c476-5
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000012660_6605f6a6c0186.jpg
# sending data/avalanche_center/webscrape/Images/0808e795-2ec1-4d0d-aaf7-d1164db0c476-5.jpg
# MediaType = image
# ***************************************************
# Media Id = ec83c4a8-2099-4ade-b14c-b226bad6c60e-177e7906-bd83-11ee-81dc-339bb7ba4d47
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/318F78DD-6DA8-4452-842A-80796B909E95_65b5b8b809f62.jpeg
# sending data/avalanche_center/webscrape/Images/ec83c4a8-2099-4ade-b14c-b226bad6c60e-177e7906-bd83-11ee-81dc-339bb7ba4d47.jpg
# MediaType = image
# ***************************************************
# Media Id = 1c898c41-bce7-49bd-96a4-765efd60c590-595fcbe0-bd83-11ee-8bee-d3d3e40476c9
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_5454_65b5b924aff10.jpeg
# sending data/avalanche_center/webscrape/Images/1c898c41-bce7-49bd-96a4-765efd60c590-595fcbe0-bd83-11ee-8bee-d3d3e40476c9.jpg
# MediaType = image
# ***************************************************
# Media Id = 1c898c41-bce7-49bd-96a4-765efd60c590-5c1dc59e-bd83-11ee-bf47-b3eb9109193e
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_5464_65b5b92618c46.jpeg
# sending data/avalanche_center/webscrape/Images/1c898c41-bce7-49bd-96a4-765efd60c590-5c1dc59e-bd83-11ee-bf47-b3eb9109193e.jpg
# MediaType = image
# ***************************************************
# Media Id = 1c898c41-bce7-49bd-96a4-765efd60c590-5cb64d3c-bd83-11ee-89b9-93c65cc0ddad
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_5461_65b5b926df4b6.jpeg
# sending data/avalanche_center/webscrape/Images/1c898c41-bce7-49bd-96a4-765efd60c590-5cb64d3c-bd83-11ee-89b9-93c65cc0ddad.jpg
# MediaType = image
# ***************************************************
# Media Id = 1c898c41-bce7-49bd-96a4-765efd60c590-5d4c1128-bd83-11ee-b76a-ab0c7f63ba9c
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_5453_65b5b925e1dfd.jpeg
# sending data/avalanche_center/webscrape/Images/1c898c41-bce7-49bd-96a4-765efd60c590-5d4c1128-bd83-11ee-b76a-ab0c7f63ba9c.jpg
# MediaType = image
# ***************************************************
# Media Id = 1c898c41-bce7-49bd-96a4-765efd60c590-5dcbf3ac-bd83-11ee-ba28-1f272db0a55a
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_5457_65b5b92801e91.jpeg
# sending data/avalanche_center/webscrape/Images/1c898c41-bce7-49bd-96a4-765efd60c590-5dcbf3ac-bd83-11ee-ba28-1f272db0a55a.jpg
# MediaType = image
# ***************************************************
# Media Id = 7b668ad5-aba1-47b3-8efb-b71b5ff0d467-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1008_65bc729438e27.jpeg
# sending data/avalanche_center/webscrape/Images/7b668ad5-aba1-47b3-8efb-b71b5ff0d467-1.jpg
# MediaType = image
# ***************************************************
# Media Id = 7b668ad5-aba1-47b3-8efb-b71b5ff0d467-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1002_65bc72920576c.jpeg
# sending data/avalanche_center/webscrape/Images/7b668ad5-aba1-47b3-8efb-b71b5ff0d467-2.jpg
# MediaType = image
# ***************************************************
# Media Id = 7b668ad5-aba1-47b3-8efb-b71b5ff0d467-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1007_65bc7292e405d.jpeg
# sending data/avalanche_center/webscrape/Images/7b668ad5-aba1-47b3-8efb-b71b5ff0d467-3.jpg
# MediaType = image
# ***************************************************
# Media Id = 7b668ad5-aba1-47b3-8efb-b71b5ff0d467-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1003_65bc729045e69.jpeg
# sending data/avalanche_center/webscrape/Images/7b668ad5-aba1-47b3-8efb-b71b5ff0d467-4.jpg
# MediaType = image
# ***************************************************
# Media Id = 7b668ad5-aba1-47b3-8efb-b71b5ff0d467-5
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1006_65bc7290e0b2a.jpeg
# sending data/avalanche_center/webscrape/Images/7b668ad5-aba1-47b3-8efb-b71b5ff0d467-5.jpg
# MediaType = image
# ***************************************************
# Media Id = 7b668ad5-aba1-47b3-8efb-b71b5ff0d467-6
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_0999_65bc728c46651.jpeg
# sending data/avalanche_center/webscrape/Images/7b668ad5-aba1-47b3-8efb-b71b5ff0d467-6.jpg
# MediaType = image
# ***************************************************
# Media Id = 9ee39829-e219-45e8-aaa2-72cc45a93f1e-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240203_194137691_65bed02eca7fb.MP_65bed02eca7fb.jpg
# sending data/avalanche_center/webscrape/Images/9ee39829-e219-45e8-aaa2-72cc45a93f1e-1.jpg
# MediaType = image
# ***************************************************
# Media Id = 9ee39829-e219-45e8-aaa2-72cc45a93f1e-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240203_203529218_65bed03038c45.MP_65bed03038c45.jpg
# sending data/avalanche_center/webscrape/Images/9ee39829-e219-45e8-aaa2-72cc45a93f1e-2.jpg
# MediaType = image
# ***************************************************
# Media Id = 9ee39829-e219-45e8-aaa2-72cc45a93f1e-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240203_193024528_65bed029ca594.MP_65bed029ca594.jpg
# sending data/avalanche_center/webscrape/Images/9ee39829-e219-45e8-aaa2-72cc45a93f1e-3.jpg
# MediaType = image
# ***************************************************
# Media Id = 9ee39829-e219-45e8-aaa2-72cc45a93f1e-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240203_194451609_65bed0300ead7.MP_65bed0300ead7.jpg
# sending data/avalanche_center/webscrape/Images/9ee39829-e219-45e8-aaa2-72cc45a93f1e-4.jpg
# MediaType = image
# ***************************************************
# Media Id = f632d94a-668a-4ab6-a030-b4869df0d973-c5d2aff8-c22a-11ee-bacc-632858e82771
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3966_65bd880640a8a.jpg
# sending data/avalanche_center/webscrape/Images/f632d94a-668a-4ab6-a030-b4869df0d973-c5d2aff8-c22a-11ee-bacc-632858e82771.jpg
# MediaType = image
# ***************************************************
# Media Id = f632d94a-668a-4ab6-a030-b4869df0d973-c6b807d8-c22a-11ee-8d8b-33a615f2a6e5
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3981_65bd8806d952f.jpg
# sending data/avalanche_center/webscrape/Images/f632d94a-668a-4ab6-a030-b4869df0d973-c6b807d8-c22a-11ee-8d8b-33a615f2a6e5.jpg
# MediaType = image
# ***************************************************
# Media Id = f632d94a-668a-4ab6-a030-b4869df0d973-c8ca6728-c22a-11ee-9abd-1fb17a6f456d
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3978_65bd88099db23.jpg
# sending data/avalanche_center/webscrape/Images/f632d94a-668a-4ab6-a030-b4869df0d973-c8ca6728-c22a-11ee-9abd-1fb17a6f456d.jpg
# MediaType = image
# ***************************************************
# Media Id = f632d94a-668a-4ab6-a030-b4869df0d973-ca57333c-c22a-11ee-b7a9-2f71c316e7ba
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3984_65bd8809ba1fb.jpg
# sending data/avalanche_center/webscrape/Images/f632d94a-668a-4ab6-a030-b4869df0d973-ca57333c-c22a-11ee-b7a9-2f71c316e7ba.jpg
# MediaType = image
# ***************************************************
# Media Id = f632d94a-668a-4ab6-a030-b4869df0d973-ca63b8be-c22a-11ee-8b87-ef1f4dcecd26
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3955_65bd880a981b1.jpg
# sending data/avalanche_center/webscrape/Images/f632d94a-668a-4ab6-a030-b4869df0d973-ca63b8be-c22a-11ee-8b87-ef1f4dcecd26.jpg
# MediaType = image
# ***************************************************
# Media Id = f632d94a-668a-4ab6-a030-b4869df0d973-ca8801a6-c22a-11ee-9a19-9f97f2c88afd
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3956_65bd880b0e4b8.jpg
# sending data/avalanche_center/webscrape/Images/f632d94a-668a-4ab6-a030-b4869df0d973-ca8801a6-c22a-11ee-9a19-9f97f2c88afd.jpg
# MediaType = image
# ***************************************************
# Media Id = b2230dba-dc5f-4e61-b524-f55b9053befa-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3881_65bd85d2cabbf.jpeg
# sending data/avalanche_center/webscrape/Images/b2230dba-dc5f-4e61-b524-f55b9053befa-1.jpg
# MediaType = image
# ***************************************************
# Media Id = b2230dba-dc5f-4e61-b524-f55b9053befa-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3889_65bd864a8ffde.jpeg
# sending data/avalanche_center/webscrape/Images/b2230dba-dc5f-4e61-b524-f55b9053befa-2.jpg
# MediaType = image
# ***************************************************
# Media Id = b2230dba-dc5f-4e61-b524-f55b9053befa-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3876_65bd85e24a74d.jpeg
# sending data/avalanche_center/webscrape/Images/b2230dba-dc5f-4e61-b524-f55b9053befa-3.jpg
# MediaType = image
# ***************************************************
# Media Id = b2230dba-dc5f-4e61-b524-f55b9053befa-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3890_65bd85f1764bf.jpeg
# sending data/avalanche_center/webscrape/Images/b2230dba-dc5f-4e61-b524-f55b9053befa-4.jpg
# MediaType = image
# ***************************************************
# Media Id = b2230dba-dc5f-4e61-b524-f55b9053befa-5
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3880_65bd85d50ccc5.jpeg
# sending data/avalanche_center/webscrape/Images/b2230dba-dc5f-4e61-b524-f55b9053befa-5.jpg
# MediaType = image
# ***************************************************
# Media Id = a3616e37-e581-45df-9e3c-6bac9ebac8f2-14a7d202-c235-11ee-a4cf-bfe40371039f
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1657_65bd994fe888f.jpg
# sending data/avalanche_center/webscrape/Images/a3616e37-e581-45df-9e3c-6bac9ebac8f2-14a7d202-c235-11ee-a4cf-bfe40371039f.jpg
# MediaType = image
# ***************************************************
# Media Id = a3616e37-e581-45df-9e3c-6bac9ebac8f2-14f8aa7e-c235-11ee-b629-075820a8ae5f
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1658_65bd994ff23eb.jpg
# sending data/avalanche_center/webscrape/Images/a3616e37-e581-45df-9e3c-6bac9ebac8f2-14f8aa7e-c235-11ee-b629-075820a8ae5f.jpg
# MediaType = image
# ***************************************************
# Media Id = a3616e37-e581-45df-9e3c-6bac9ebac8f2-1560ad72-c235-11ee-a9a8-13d87133f7bb
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1661_65bd99523f02f.jpg
# sending data/avalanche_center/webscrape/Images/a3616e37-e581-45df-9e3c-6bac9ebac8f2-1560ad72-c235-11ee-a9a8-13d87133f7bb.jpg
# MediaType = image
# ***************************************************
# Media Id = 768826db-8953-4f35-b2b3-626e9d7935a7-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240128_193031443_65b6bd2f0aac1.jpg
# sending data/avalanche_center/webscrape/Images/768826db-8953-4f35-b2b3-626e9d7935a7-1.jpg
# MediaType = image
# ***************************************************
# Media Id = 768826db-8953-4f35-b2b3-626e9d7935a7-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240128_183030552_65b6bd2e0aff9.jpg
# sending data/avalanche_center/webscrape/Images/768826db-8953-4f35-b2b3-626e9d7935a7-2.jpg
# MediaType = image
# ***************************************************
# Media Id = 768826db-8953-4f35-b2b3-626e9d7935a7-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240128_184918448_65b6bd2de5a3b.PANO_65b6bd2de5a3b.jpg
# sending data/avalanche_center/webscrape/Images/768826db-8953-4f35-b2b3-626e9d7935a7-3.jpg
# MediaType = image
# ***************************************************
# Media Id = 768826db-8953-4f35-b2b3-626e9d7935a7-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240128_175220843_65b6bd2bcc0c2.jpg
# sending data/avalanche_center/webscrape/Images/768826db-8953-4f35-b2b3-626e9d7935a7-4.jpg
# MediaType = image
# ***************************************************
# Media Id = ee886411-0300-441b-ad6b-6f6634373021-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000011104_65bd71e8e31be.jpg
# sending data/avalanche_center/webscrape/Images/ee886411-0300-441b-ad6b-6f6634373021-1.jpg
# MediaType = image
# ***************************************************
# Media Id = ee886411-0300-441b-ad6b-6f6634373021-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000011115_65bd71e6c6b3e.jpg
# sending data/avalanche_center/webscrape/Images/ee886411-0300-441b-ad6b-6f6634373021-2.jpg
# MediaType = image
# ***************************************************
# Media Id = ee886411-0300-441b-ad6b-6f6634373021-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000011112_65bd71e44cb80.jpg
# sending data/avalanche_center/webscrape/Images/ee886411-0300-441b-ad6b-6f6634373021-3.jpg
# MediaType = video
# Skipping MediaType = video
# ***************************************************
# Media Id = a2a3d514-c2f9-4847-a4b2-13979751ece5-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/null_65b70a30a5818.jpg
# sending data/avalanche_center/webscrape/Images/a2a3d514-c2f9-4847-a4b2-13979751ece5-1.jpg
# MediaType = image
# ***************************************************
# Media Id = a2a3d514-c2f9-4847-a4b2-13979751ece5-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_0911_65b7087c8682f.jpeg
# sending data/avalanche_center/webscrape/Images/a2a3d514-c2f9-4847-a4b2-13979751ece5-2.jpg
# MediaType = image
# ***************************************************
# Media Id = a2a3d514-c2f9-4847-a4b2-13979751ece5-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_0919_65b7087df260e.jpeg
# sending data/avalanche_center/webscrape/Images/a2a3d514-c2f9-4847-a4b2-13979751ece5-3.jpg
# MediaType = image
# ***************************************************
# Media Id = a2a3d514-c2f9-4847-a4b2-13979751ece5-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_0906_65b7087ef17c7.jpeg
# sending data/avalanche_center/webscrape/Images/a2a3d514-c2f9-4847-a4b2-13979751ece5-4.jpg
# MediaType = image
# ***************************************************
# Media Id = a2a3d514-c2f9-4847-a4b2-13979751ece5-5
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/image_65b7088d90950.png
# sending data/avalanche_center/webscrape/Images/a2a3d514-c2f9-4847-a4b2-13979751ece5-5.jpg
# MediaType = image
# ***************************************************
# Media Id = 3794abbb-8f78-4fab-bfd8-df9636db9cf7-0ce7b73c-be69-11ee-a17d-2f60b66b8b91
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3122_65b73a8731b4a.jpeg
# sending data/avalanche_center/webscrape/Images/3794abbb-8f78-4fab-bfd8-df9636db9cf7-0ce7b73c-be69-11ee-a17d-2f60b66b8b91.jpg
# MediaType = image
# ***************************************************
# Media Id = 3794abbb-8f78-4fab-bfd8-df9636db9cf7-0ec8f048-be69-11ee-801a-7b45ab934fea
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_7106_65b73a89883d0.jpeg
# sending data/avalanche_center/webscrape/Images/3794abbb-8f78-4fab-bfd8-df9636db9cf7-0ec8f048-be69-11ee-801a-7b45ab934fea.jpg
# MediaType = image
# ***************************************************
# Media Id = 3794abbb-8f78-4fab-bfd8-df9636db9cf7-0ff0b1d6-be69-11ee-b541-87735bf7b9dd
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_7101_65b73a8b5e2ed.jpeg
# sending data/avalanche_center/webscrape/Images/3794abbb-8f78-4fab-bfd8-df9636db9cf7-0ff0b1d6-be69-11ee-b541-87735bf7b9dd.jpg
# MediaType = image
# ***************************************************
# Media Id = 4b4ce3fc-aab4-4ef7-bd6c-58d983984509-ac2acb7e-be6c-11ee-ae32-7bcd86875d20
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_5467_65b740999b144.jpeg
# sending data/avalanche_center/webscrape/Images/4b4ce3fc-aab4-4ef7-bd6c-58d983984509-ac2acb7e-be6c-11ee-ae32-7bcd86875d20.jpg
# MediaType = image
# ***************************************************
# Media Id = 4b4ce3fc-aab4-4ef7-bd6c-58d983984509-acb8624a-be6c-11ee-8baf-477d11995883
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_5466_65b7409a1ca91.jpeg
# sending data/avalanche_center/webscrape/Images/4b4ce3fc-aab4-4ef7-bd6c-58d983984509-acb8624a-be6c-11ee-8baf-477d11995883.jpg
# MediaType = image
# ***************************************************
# Media Id = b5c1bdf9-0771-4b68-97e3-93bc156ed690-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_4079_65caac8562920.jpeg
# sending data/avalanche_center/webscrape/Images/b5c1bdf9-0771-4b68-97e3-93bc156ed690-1.jpg
# MediaType = image
# ***************************************************
# Media Id = b5c1bdf9-0771-4b68-97e3-93bc156ed690-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_4081_65caac8a7a7a3.jpeg
# sending data/avalanche_center/webscrape/Images/b5c1bdf9-0771-4b68-97e3-93bc156ed690-2.jpg
# MediaType = image
# ***************************************************
# Media Id = b5c1bdf9-0771-4b68-97e3-93bc156ed690-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_4072_65caac8b12511.jpeg
# sending data/avalanche_center/webscrape/Images/b5c1bdf9-0771-4b68-97e3-93bc156ed690-3.jpg
# MediaType = image
# ***************************************************
# Media Id = b5c1bdf9-0771-4b68-97e3-93bc156ed690-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_4071_65caac7e02689.jpeg
# sending data/avalanche_center/webscrape/Images/b5c1bdf9-0771-4b68-97e3-93bc156ed690-4.jpg
# MediaType = image
# ***************************************************
# Media Id = b5c1bdf9-0771-4b68-97e3-93bc156ed690-5
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_4075_65caac88f0f11.jpeg
# sending data/avalanche_center/webscrape/Images/b5c1bdf9-0771-4b68-97e3-93bc156ed690-5.jpg
# MediaType = image
# ***************************************************
# Media Id = b5c1bdf9-0771-4b68-97e3-93bc156ed690-6
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_4082_65caac8b0f80b.jpeg
# sending data/avalanche_center/webscrape/Images/b5c1bdf9-0771-4b68-97e3-93bc156ed690-6.jpg
# MediaType = image
# ***************************************************
# Media Id = 7713ed09-94b6-465f-a6bc-fe59e894fc69-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_7161_65b815724e17c.jpg
# sending data/avalanche_center/webscrape/Images/7713ed09-94b6-465f-a6bc-fe59e894fc69-1.jpg
# MediaType = image
# ***************************************************
# Media Id = 7713ed09-94b6-465f-a6bc-fe59e894fc69-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_7172_65b81573b2bbb.jpg
# sending data/avalanche_center/webscrape/Images/7713ed09-94b6-465f-a6bc-fe59e894fc69-2.jpg
# MediaType = image
# ***************************************************
# Media Id = 7713ed09-94b6-465f-a6bc-fe59e894fc69-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_7158_65b815711d8ca.jpg
# sending data/avalanche_center/webscrape/Images/7713ed09-94b6-465f-a6bc-fe59e894fc69-3.jpg
# MediaType = image
# ***************************************************
# Media Id = 7713ed09-94b6-465f-a6bc-fe59e894fc69-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_7167_65b8157300f1d.jpg
# sending data/avalanche_center/webscrape/Images/7713ed09-94b6-465f-a6bc-fe59e894fc69-4.jpg
# MediaType = image
# ***************************************************
# Media Id = 7713ed09-94b6-465f-a6bc-fe59e894fc69-5
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_7169_65b81575082da.jpg
# sending data/avalanche_center/webscrape/Images/7713ed09-94b6-465f-a6bc-fe59e894fc69-5.jpg
# MediaType = image
# ***************************************************
# Media Id = 4c19b99c-45ec-48fa-936b-2b30f9652539-a263f13a-bf14-11ee-b75b-4331f4c1df6e
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_9075_65b85a67481cf.jpeg
# sending data/avalanche_center/webscrape/Images/4c19b99c-45ec-48fa-936b-2b30f9652539-a263f13a-bf14-11ee-b75b-4331f4c1df6e.jpg
# MediaType = image
# ***************************************************
# Media Id = 4c19b99c-45ec-48fa-936b-2b30f9652539-acbdff5e-bf14-11ee-aa89-b770b531d351
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_9061_65b85a77692c6.jpeg
# sending data/avalanche_center/webscrape/Images/4c19b99c-45ec-48fa-936b-2b30f9652539-acbdff5e-bf14-11ee-aa89-b770b531d351.jpg
# MediaType = image
# ***************************************************
# Media Id = 369a2085-cfdb-4523-873b-635b10e590a4-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000011013_65b8763a2e1ba.jpg
# sending data/avalanche_center/webscrape/Images/369a2085-cfdb-4523-873b-635b10e590a4-1.jpg
# MediaType = image
# ***************************************************
# Media Id = 369a2085-cfdb-4523-873b-635b10e590a4-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000011006_65b8763d5624f.jpg
# sending data/avalanche_center/webscrape/Images/369a2085-cfdb-4523-873b-635b10e590a4-2.jpg
# MediaType = image
# ***************************************************
# Media Id = 369a2085-cfdb-4523-873b-635b10e590a4-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3802_65b85fb61a2f4.jpeg
# sending data/avalanche_center/webscrape/Images/369a2085-cfdb-4523-873b-635b10e590a4-3.jpg
# MediaType = image
# ***************************************************
# Media Id = 369a2085-cfdb-4523-873b-635b10e590a4-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3797_65b85fb2152ed.jpeg
# sending data/avalanche_center/webscrape/Images/369a2085-cfdb-4523-873b-635b10e590a4-4.jpg
# MediaType = image
# ***************************************************
# Media Id = b1d3b283-8445-49e9-a04c-329d237e931c-924b9f84-c3e5-11ee-b5eb-1f9c1d5059c6
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_20240204_211209_65c06eed8dedb.jpg
# sending data/avalanche_center/webscrape/Images/b1d3b283-8445-49e9-a04c-329d237e931c-924b9f84-c3e5-11ee-b5eb-1f9c1d5059c6.jpg
# MediaType = image
# ***************************************************
# Media Id = 60ece7c4-3cb1-49e7-a76b-75651545afdc-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240130_171239291_65b9666e61e8c.jpg
# sending data/avalanche_center/webscrape/Images/60ece7c4-3cb1-49e7-a76b-75651545afdc-1.jpg
# MediaType = image
# ***************************************************
# Media Id = 60ece7c4-3cb1-49e7-a76b-75651545afdc-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240130_190121260_65b9668519dc2.jpg
# sending data/avalanche_center/webscrape/Images/60ece7c4-3cb1-49e7-a76b-75651545afdc-2.jpg
# MediaType = image
# ***************************************************
# Media Id = 60ece7c4-3cb1-49e7-a76b-75651545afdc-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000011040_65b9620f20d61.jpg
# sending data/avalanche_center/webscrape/Images/60ece7c4-3cb1-49e7-a76b-75651545afdc-3.jpg
# MediaType = image
# ***************************************************
# Media Id = 60ece7c4-3cb1-49e7-a76b-75651545afdc-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000011049_65b96224af810.jpg
# sending data/avalanche_center/webscrape/Images/60ece7c4-3cb1-49e7-a76b-75651545afdc-4.jpg
# MediaType = image
# ***************************************************
# Media Id = a7a769af-dffd-4942-ba12-eb9e0031b4d6-ce1da958-bfda-11ee-8cb4-ef7748933e9e
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_7614_65b9a6dfe8a3d.jpeg
# sending data/avalanche_center/webscrape/Images/a7a769af-dffd-4942-ba12-eb9e0031b4d6-ce1da958-bfda-11ee-8cb4-ef7748933e9e.jpg
# MediaType = image
# ***************************************************
# Media Id = bbd6bd1b-0e4f-48db-b279-05dc32e5dbaa-bc6f8bc2-c304-11ee-a6da-2f79278ad11e
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/82346D78-9B25-4D92-A036-4CF0C4310A78_65bef5b66d804.jpeg
# sending data/avalanche_center/webscrape/Images/bbd6bd1b-0e4f-48db-b279-05dc32e5dbaa-bc6f8bc2-c304-11ee-a6da-2f79278ad11e.jpg
# MediaType = image
# ***************************************************
# Media Id = bbd6bd1b-0e4f-48db-b279-05dc32e5dbaa-bd551322-c304-11ee-b092-6f1a7a45f0b8
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/30FE8436-7FE3-4817-9D4D-D7A5D3C496DB_65bef5b7e753c.jpeg
# sending data/avalanche_center/webscrape/Images/bbd6bd1b-0e4f-48db-b279-05dc32e5dbaa-bd551322-c304-11ee-b092-6f1a7a45f0b8.jpg
# MediaType = image
# ***************************************************
# Media Id = 6b9f8280-0159-488c-96e5-3e45e0dbf546-0e467692-bfe8-11ee-a5a4-3fecfe4cb2c2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_6795_65b9bd1690dc6.jpeg
# sending data/avalanche_center/webscrape/Images/6b9f8280-0159-488c-96e5-3e45e0dbf546-0e467692-bfe8-11ee-a5a4-3fecfe4cb2c2.jpg
# MediaType = image
# ***************************************************
# Media Id = 6b9f8280-0159-488c-96e5-3e45e0dbf546-0e7e2010-bfe8-11ee-9981-ff18575968f1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_6796_65b9bd16720cb.jpeg
# sending data/avalanche_center/webscrape/Images/6b9f8280-0159-488c-96e5-3e45e0dbf546-0e7e2010-bfe8-11ee-9981-ff18575968f1.jpg
# MediaType = image
# ***************************************************
# Media Id = f78d77f4-f18e-4c9d-855d-63875877574a-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000011160_65beea4b0d8ec.jpg
# sending data/avalanche_center/webscrape/Images/f78d77f4-f18e-4c9d-855d-63875877574a-1.jpg
# MediaType = image
# ***************************************************
# Media Id = f78d77f4-f18e-4c9d-855d-63875877574a-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_5293_65bee3593cc12.jpg
# sending data/avalanche_center/webscrape/Images/f78d77f4-f18e-4c9d-855d-63875877574a-2.jpg
# MediaType = image
# ***************************************************
# Media Id = f78d77f4-f18e-4c9d-855d-63875877574a-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000011159_65bedd949c023.jpg
# sending data/avalanche_center/webscrape/Images/f78d77f4-f18e-4c9d-855d-63875877574a-3.jpg
# MediaType = image
# ***************************************************
# Media Id = 339af770-1ac5-444c-97a0-a43c7dae0c85-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3838_65b9a20563106.jpeg
# sending data/avalanche_center/webscrape/Images/339af770-1ac5-444c-97a0-a43c7dae0c85-1.jpg
# MediaType = image
# ***************************************************
# Media Id = 339af770-1ac5-444c-97a0-a43c7dae0c85-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3816_65b9a1eeae38d.jpeg
# sending data/avalanche_center/webscrape/Images/339af770-1ac5-444c-97a0-a43c7dae0c85-2.jpg
# MediaType = image
# ***************************************************
# Media Id = 339af770-1ac5-444c-97a0-a43c7dae0c85-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3826_65b9a1f677f79.jpeg
# sending data/avalanche_center/webscrape/Images/339af770-1ac5-444c-97a0-a43c7dae0c85-3.jpg
# MediaType = image
# ***************************************************
# Media Id = 339af770-1ac5-444c-97a0-a43c7dae0c85-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3834_65b9a1fa8032d.jpeg
# sending data/avalanche_center/webscrape/Images/339af770-1ac5-444c-97a0-a43c7dae0c85-4.jpg
# MediaType = image
# ***************************************************
# Media Id = 339af770-1ac5-444c-97a0-a43c7dae0c85-5
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_3813_65b9a202719e9.jpeg
# sending data/avalanche_center/webscrape/Images/339af770-1ac5-444c-97a0-a43c7dae0c85-5.jpg
# MediaType = image
# ***************************************************
# Media Id = 2ca670dc-10f6-46fe-a9c8-7affa186c564-56397e48-c657-11ee-8e60-931d4abdedca
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/Broccoli%20Chutes-07-Feb_65c488ca0da7d.jpg
# sending data/avalanche_center/webscrape/Images/2ca670dc-10f6-46fe-a9c8-7affa186c564-56397e48-c657-11ee-8e60-931d4abdedca.jpg
# MediaType = image
# ***************************************************
# Media Id = af6f81ab-6860-4e58-a7ca-73f180341d16-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240131_171845847~2_65baa715d77d9.jpg
# sending data/avalanche_center/webscrape/Images/af6f81ab-6860-4e58-a7ca-73f180341d16-1.jpg
# MediaType = image
# ***************************************************
# Media Id = af6f81ab-6860-4e58-a7ca-73f180341d16-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240131_175902662_65baa71902a46.PANO_65baa71902a46.jpg
# sending data/avalanche_center/webscrape/Images/af6f81ab-6860-4e58-a7ca-73f180341d16-2.jpg
# MediaType = image
# ***************************************************
# Media Id = af6f81ab-6860-4e58-a7ca-73f180341d16-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240131_182215605_65baa719ef4da.jpg
# sending data/avalanche_center/webscrape/Images/af6f81ab-6860-4e58-a7ca-73f180341d16-3.jpg
# MediaType = image
# ***************************************************
# Media Id = af6f81ab-6860-4e58-a7ca-73f180341d16-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240131_173127363_65baa71a1545c.jpg
# sending data/avalanche_center/webscrape/Images/af6f81ab-6860-4e58-a7ca-73f180341d16-4.jpg
# MediaType = image
# ***************************************************
# Media Id = 713cbb37-2aca-4434-b6a7-54029c80b239-9bcc9ece-c6dc-11ee-9e35-c309cdd57c8f
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/0CF3C853-956B-4FEB-BCDA-64C41B2624B2_1_105_c_65c56861b008f.jpeg
# sending data/avalanche_center/webscrape/Images/713cbb37-2aca-4434-b6a7-54029c80b239-9bcc9ece-c6dc-11ee-9e35-c309cdd57c8f.jpg
# MediaType = image
# ***************************************************
# Media Id = 713cbb37-2aca-4434-b6a7-54029c80b239-9e98ae4a-c6dc-11ee-97ef-2f1f4a283f2d
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/CF68A218-5F83-4171-96BD-3A47753E885A_1_102_o_65c56865cfdff.jpeg
# sending data/avalanche_center/webscrape/Images/713cbb37-2aca-4434-b6a7-54029c80b239-9e98ae4a-c6dc-11ee-97ef-2f1f4a283f2d.jpg
# MediaType = image
# ***************************************************
# Media Id = 713cbb37-2aca-4434-b6a7-54029c80b239-9fb2f952-c6dc-11ee-b961-47a4136bf711
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/5265539B-4A0D-40E6-9258-183ABB129166_1_102_o_65c5686781714.jpeg
# sending data/avalanche_center/webscrape/Images/713cbb37-2aca-4434-b6a7-54029c80b239-9fb2f952-c6dc-11ee-b961-47a4136bf711.jpg
# MediaType = image
# ***************************************************
# Media Id = 713cbb37-2aca-4434-b6a7-54029c80b239-9fcbd59e-c6dc-11ee-9989-cf62be42b240
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/C91AEBC5-283E-49FC-8012-D86B4E0D30D4_1_102_o_65c56867a35eb.jpeg
# sending data/avalanche_center/webscrape/Images/713cbb37-2aca-4434-b6a7-54029c80b239-9fcbd59e-c6dc-11ee-9989-cf62be42b240.jpg
# MediaType = image
# ***************************************************
# Media Id = 713cbb37-2aca-4434-b6a7-54029c80b239-a04b27c2-c6dc-11ee-8634-2b47c58c7893
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/976A8637-C907-42DA-A468-DC5070153B04_1_102_o_65c568688695f.jpeg
# sending data/avalanche_center/webscrape/Images/713cbb37-2aca-4434-b6a7-54029c80b239-a04b27c2-c6dc-11ee-8634-2b47c58c7893.jpg
# MediaType = image
# ***************************************************
# Media Id = f55b128b-cd38-474e-a4de-1edba8d74c17-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_2455_65bacd274b6ee.jpg
# sending data/avalanche_center/webscrape/Images/f55b128b-cd38-474e-a4de-1edba8d74c17-1.jpg
# MediaType = image
# ***************************************************
# Media Id = f55b128b-cd38-474e-a4de-1edba8d74c17-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_2456_65bacd2883873.jpg
# sending data/avalanche_center/webscrape/Images/f55b128b-cd38-474e-a4de-1edba8d74c17-2.jpg
# MediaType = image
# ***************************************************
# Media Id = f55b128b-cd38-474e-a4de-1edba8d74c17-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240131_191531992_65bacd28c870d.MP_65bacd28c870d.jpg
# sending data/avalanche_center/webscrape/Images/f55b128b-cd38-474e-a4de-1edba8d74c17-3.jpg
# MediaType = image
# ***************************************************
# Media Id = f55b128b-cd38-474e-a4de-1edba8d74c17-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240131_184359502_65bacd2a853aa.MP_65bacd2a853aa.jpg
# sending data/avalanche_center/webscrape/Images/f55b128b-cd38-474e-a4de-1edba8d74c17-4.jpg
# MediaType = image
# ***************************************************
# Media Id = f55b128b-cd38-474e-a4de-1edba8d74c17-5
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/Screenshot_20240131-121016_65bacd2731375.png
# sending data/avalanche_center/webscrape/Images/f55b128b-cd38-474e-a4de-1edba8d74c17-5.jpg
# MediaType = image
# ***************************************************
# Media Id = e67d6105-edf4-4d99-9a66-f67dfed4b5b4-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000011090_65bade9458fc0.jpg
# sending data/avalanche_center/webscrape/Images/e67d6105-edf4-4d99-9a66-f67dfed4b5b4-1.jpg
# MediaType = image
# ***************************************************
# Media Id = e67d6105-edf4-4d99-9a66-f67dfed4b5b4-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000011070_65bade901a7e2.jpg
# sending data/avalanche_center/webscrape/Images/e67d6105-edf4-4d99-9a66-f67dfed4b5b4-2.jpg
# MediaType = image
# ***************************************************
# Media Id = e67d6105-edf4-4d99-9a66-f67dfed4b5b4-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000011080_65bade91e525d.jpg
# sending data/avalanche_center/webscrape/Images/e67d6105-edf4-4d99-9a66-f67dfed4b5b4-3.jpg
# MediaType = image
# ***************************************************
# Media Id = c79a09c7-fdd6-4adf-8c21-c0e3c5c85a6e-5c1bfab2-c7d2-11ee-af28-9f4b0420cbd2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240209_185454229_65c704ae396a9.MP_65c704ae396a9.jpg
# sending data/avalanche_center/webscrape/Images/c79a09c7-fdd6-4adf-8c21-c0e3c5c85a6e-5c1bfab2-c7d2-11ee-af28-9f4b0420cbd2.jpg
# MediaType = image
# ***************************************************
# Media Id = 7ff0a30b-4058-4626-815b-858714b705da-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240205_184413155_65c16862cb890.jpg
# sending data/avalanche_center/webscrape/Images/7ff0a30b-4058-4626-815b-858714b705da-1.jpg
# MediaType = image
# ***************************************************
# Media Id = 7ff0a30b-4058-4626-815b-858714b705da-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240205_210625498_65c1686388303.jpg
# sending data/avalanche_center/webscrape/Images/7ff0a30b-4058-4626-815b-858714b705da-2.jpg
# MediaType = image
# ***************************************************
# Media Id = 7ff0a30b-4058-4626-815b-858714b705da-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240205_193208637_65c168626c8f7.jpg
# sending data/avalanche_center/webscrape/Images/7ff0a30b-4058-4626-815b-858714b705da-3.jpg
# MediaType = image
# ***************************************************
# Media Id = 7ff0a30b-4058-4626-815b-858714b705da-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240205_190713804_65c1686047db9.jpg
# sending data/avalanche_center/webscrape/Images/7ff0a30b-4058-4626-815b-858714b705da-4.jpg
# MediaType = image
# ***************************************************
# Media Id = 7ff0a30b-4058-4626-815b-858714b705da-5
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240205_190842003_65c16861e803e.PANO_65c16861e803e.jpg
# sending data/avalanche_center/webscrape/Images/7ff0a30b-4058-4626-815b-858714b705da-5.jpg
# MediaType = image
# ***************************************************
# Media Id = 750538a9-4232-4833-bde2-88062c6e26ba-7edcad1e-bb3c-11ee-80c5-c37b0bffd45b
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_20240124_190607_605_65b1e74b0003e.jpg
# sending data/avalanche_center/webscrape/Images/750538a9-4232-4833-bde2-88062c6e26ba-7edcad1e-bb3c-11ee-80c5-c37b0bffd45b.jpg
# MediaType = image
# ***************************************************
# ...
# MediaType = image
# ***************************************************
# Media Id = be2c9c2d-6ef0-44d8-a066-230fc6a89f6c-5
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240326_175458799_660336248aa38.MP_660336248aa38.jpg
# sending data/avalanche_center/webscrape/Images/be2c9c2d-6ef0-44d8-a066-230fc6a89f6c-5.jpg
# MediaType = image
# ***************************************************
# Media Id = be2c9c2d-6ef0-44d8-a066-230fc6a89f6c-6
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240326_190830864_66033625b008b.MP_66033625b008b.jpg
# sending data/avalanche_center/webscrape/Images/be2c9c2d-6ef0-44d8-a066-230fc6a89f6c-6.jpg
# MediaType = image
# ***************************************************
# Media Id = 55affe18-a743-4822-9c59-447140e3b4aa-47405e02-ebe1-11ee-95ef-472e5b3c5ee0
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_2030_660383945c5d5.jpeg
# sending data/avalanche_center/webscrape/Images/55affe18-a743-4822-9c59-447140e3b4aa-47405e02-ebe1-11ee-95ef-472e5b3c5ee0.jpg
# MediaType = image
# ***************************************************
# Media Id = 55affe18-a743-4822-9c59-447140e3b4aa-4797acca-ebe1-11ee-8099-073fe446ad40
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_2028_660383943fc5d.jpeg
# sending data/avalanche_center/webscrape/Images/55affe18-a743-4822-9c59-447140e3b4aa-4797acca-ebe1-11ee-8099-073fe446ad40.jpg
# MediaType = image
# ***************************************************
# Media Id = 55affe18-a743-4822-9c59-447140e3b4aa-47eaf10a-ebe1-11ee-ab20-1f9ae3411d5d
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_2031_66038394b40cb.jpeg
# sending data/avalanche_center/webscrape/Images/55affe18-a743-4822-9c59-447140e3b4aa-47eaf10a-ebe1-11ee-ab20-1f9ae3411d5d.jpg
# MediaType = image
# ***************************************************
# Media Id = 0611a104-0bbc-4da9-b973-de37ef528fd2-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000012552_66038db94d23a.jpg
# sending data/avalanche_center/webscrape/Images/0611a104-0bbc-4da9-b973-de37ef528fd2-1.jpg
# MediaType = image
# ***************************************************
# Media Id = 0611a104-0bbc-4da9-b973-de37ef528fd2-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000012583_6603878e1cde5.jpg
# sending data/avalanche_center/webscrape/Images/0611a104-0bbc-4da9-b973-de37ef528fd2-2.jpg
# MediaType = image
# ***************************************************
# Media Id = 0611a104-0bbc-4da9-b973-de37ef528fd2-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000012584_6603878b0709a.jpg
# sending data/avalanche_center/webscrape/Images/0611a104-0bbc-4da9-b973-de37ef528fd2-3.jpg
# MediaType = image
# ***************************************************
# Media Id = 0611a104-0bbc-4da9-b973-de37ef528fd2-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000012560_6603878a31154.jpg
# sending data/avalanche_center/webscrape/Images/0611a104-0bbc-4da9-b973-de37ef528fd2-4.jpg
# MediaType = image
# ***************************************************
# Media Id = 0611a104-0bbc-4da9-b973-de37ef528fd2-5
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/1000012545_6603878e099a4.jpg
# sending data/avalanche_center/webscrape/Images/0611a104-0bbc-4da9-b973-de37ef528fd2-5.jpg
# MediaType = image
# ***************************************************
# Media Id = e1a3f208-fa2f-4906-9d97-54651852c64e-2a75aa0c-ec68-11ee-8016-03662de63f20
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/FAA3C668-0746-4755-BACE-1477E1474922_660465e5db2de.jpeg
# sending data/avalanche_center/webscrape/Images/e1a3f208-fa2f-4906-9d97-54651852c64e-2a75aa0c-ec68-11ee-8016-03662de63f20.jpg
# MediaType = image
# ***************************************************
# Media Id = e1a3f208-fa2f-4906-9d97-54651852c64e-2dd28576-ec68-11ee-9bec-bfd5640a6fe8
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1144_660465eb17420.jpeg
# sending data/avalanche_center/webscrape/Images/e1a3f208-fa2f-4906-9d97-54651852c64e-2dd28576-ec68-11ee-9bec-bfd5640a6fe8.jpg
# MediaType = image
# ***************************************************
# Media Id = e1a3f208-fa2f-4906-9d97-54651852c64e-2f25f520-ec68-11ee-abc1-6f7ad656a41b
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1948_660465eccd009.jpeg
# sending data/avalanche_center/webscrape/Images/e1a3f208-fa2f-4906-9d97-54651852c64e-2f25f520-ec68-11ee-abc1-6f7ad656a41b.jpg
# MediaType = image
# ***************************************************
# Media Id = e2eab136-8bb1-49de-824a-4668b9b88ef7-e726d4f6-ebd1-11ee-936e-8b5280f60f3b
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_5188_660369cc9513a.jpeg
# sending data/avalanche_center/webscrape/Images/e2eab136-8bb1-49de-824a-4668b9b88ef7-e726d4f6-ebd1-11ee-936e-8b5280f60f3b.jpg
# MediaType = image
# ***************************************************
# Media Id = 4c02df1a-af41-422e-9e4c-0fd319e3b8b7-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240327_183912434_66048a985719e.jpg
# sending data/avalanche_center/webscrape/Images/4c02df1a-af41-422e-9e4c-0fd319e3b8b7-1.jpg
# MediaType = image
# ***************************************************
# Media Id = 4c02df1a-af41-422e-9e4c-0fd319e3b8b7-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240327_183332419_66048a9649fb0.jpg
# sending data/avalanche_center/webscrape/Images/4c02df1a-af41-422e-9e4c-0fd319e3b8b7-2.jpg
# MediaType = image
# ***************************************************
# Media Id = 4c02df1a-af41-422e-9e4c-0fd319e3b8b7-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240327_165705905_66048a96b1c87.jpg
# sending data/avalanche_center/webscrape/Images/4c02df1a-af41-422e-9e4c-0fd319e3b8b7-3.jpg
# MediaType = image
# ***************************************************
# Media Id = 4c02df1a-af41-422e-9e4c-0fd319e3b8b7-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240327_165146724_66048a97c9fa7.jpg
# sending data/avalanche_center/webscrape/Images/4c02df1a-af41-422e-9e4c-0fd319e3b8b7-4.jpg
# MediaType = image
# ***************************************************
# Media Id = 4c02df1a-af41-422e-9e4c-0fd319e3b8b7-5
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240327_191707560_66048a9980ad7.jpg
# sending data/avalanche_center/webscrape/Images/4c02df1a-af41-422e-9e4c-0fd319e3b8b7-5.jpg
# MediaType = image
# ***************************************************
# Media Id = 5fd8a854-d81f-47d8-b83b-72be35075c30-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240328_181823109_6605d6d52d4ab.jpg
# sending data/avalanche_center/webscrape/Images/5fd8a854-d81f-47d8-b83b-72be35075c30-1.jpg
# MediaType = image
# ***************************************************
# Media Id = 5fd8a854-d81f-47d8-b83b-72be35075c30-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240328_172440736_6605d6d76fa0d.MP_6605d6d76fa0d.jpg
# sending data/avalanche_center/webscrape/Images/5fd8a854-d81f-47d8-b83b-72be35075c30-2.jpg
# MediaType = image
# ***************************************************
# Media Id = 5fd8a854-d81f-47d8-b83b-72be35075c30-3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240328_181734861_6605d6d441257.jpg
# sending data/avalanche_center/webscrape/Images/5fd8a854-d81f-47d8-b83b-72be35075c30-3.jpg
# MediaType = image
# ***************************************************
# Media Id = 5fd8a854-d81f-47d8-b83b-72be35075c30-4
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240328_193941014_6605d6d6297fd.jpg
# sending data/avalanche_center/webscrape/Images/5fd8a854-d81f-47d8-b83b-72be35075c30-4.jpg
# MediaType = image
# ***************************************************
# Media Id = 5fd8a854-d81f-47d8-b83b-72be35075c30-5
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/PXL_20240328_174956795_6605d6d2b0b14.PANO_6605d6d2b0b14.jpg
# sending data/avalanche_center/webscrape/Images/5fd8a854-d81f-47d8-b83b-72be35075c30-5.jpg
# MediaType = image
# ***************************************************
# Media Id = c7186f79-32a9-42af-baa3-d84d8d92ea3f-6ef71f34-ee26-11ee-860f-7b1b81a3411f
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_4749_6607529be783f.jpg
# sending data/avalanche_center/webscrape/Images/c7186f79-32a9-42af-baa3-d84d8d92ea3f-6ef71f34-ee26-11ee-860f-7b1b81a3411f.jpg
# MediaType = image
# ***************************************************
# Media Id = c7186f79-32a9-42af-baa3-d84d8d92ea3f-724df64e-ee26-11ee-819d-db53dd016d52
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_4748_6607529dc2b5a.jpg
# sending data/avalanche_center/webscrape/Images/c7186f79-32a9-42af-baa3-d84d8d92ea3f-724df64e-ee26-11ee-819d-db53dd016d52.jpg
# MediaType = image
# ***************************************************
# Media Id = c7186f79-32a9-42af-baa3-d84d8d92ea3f-7576a80c-ee26-11ee-a9e6-3709a3347bd0
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_4750_6607529ee42b2.jpg
# sending data/avalanche_center/webscrape/Images/c7186f79-32a9-42af-baa3-d84d8d92ea3f-7576a80c-ee26-11ee-a9e6-3709a3347bd0.jpg
# MediaType = image
# ***************************************************
# Media Id = c7186f79-32a9-42af-baa3-d84d8d92ea3f-758a505a-ee26-11ee-bdac-ff8d8bd33345
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_4744_6607529e38cdd.jpg
# sending data/avalanche_center/webscrape/Images/c7186f79-32a9-42af-baa3-d84d8d92ea3f-758a505a-ee26-11ee-bdac-ff8d8bd33345.jpg
# MediaType = image
# ***************************************************
# Media Id = c7186f79-32a9-42af-baa3-d84d8d92ea3f-75c169c8-ee26-11ee-b88e-9ff3aa71ffd2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_4752_6607529fc66c6.jpg
# sending data/avalanche_center/webscrape/Images/c7186f79-32a9-42af-baa3-d84d8d92ea3f-75c169c8-ee26-11ee-b88e-9ff3aa71ffd2.jpg
# MediaType = image
# ***************************************************
# Media Id = 19b61baf-42c5-4215-9561-33efcfbb7c28-1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/Judah%20avalanche%202%2020240329_660755d051c56.png
# sending data/avalanche_center/webscrape/Images/19b61baf-42c5-4215-9561-33efcfbb7c28-1.jpg
# MediaType = image
# ***************************************************
# Media Id = 19b61baf-42c5-4215-9561-33efcfbb7c28-2
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/Judah%20avalanche%201%2020240329_660753fa4ea7e.png
# sending data/avalanche_center/webscrape/Images/19b61baf-42c5-4215-9561-33efcfbb7c28-2.jpg
# MediaType = image
# ***************************************************
# Media Id = 0dafc5a0-b777-417f-a24c-a5da911c8547-abec6eb6-ff5c-11ee-afe8-17c460a819c9
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_0408_6624330c7de30.jpeg
# sending data/avalanche_center/webscrape/Images/0dafc5a0-b777-417f-a24c-a5da911c8547-abec6eb6-ff5c-11ee-afe8-17c460a819c9.jpg
# MediaType = image
# ***************************************************
# Media Id = 0dafc5a0-b777-417f-a24c-a5da911c8547-af0b6b7e-ff5c-11ee-bc1b-73eb280ffdee
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_0406_66243311ba674.jpeg
# sending data/avalanche_center/webscrape/Images/0dafc5a0-b777-417f-a24c-a5da911c8547-af0b6b7e-ff5c-11ee-bc1b-73eb280ffdee.jpg
# MediaType = image
# ***************************************************
# Media Id = 608e8afe-5258-48d9-8edd-2e5732dde9b2-c3d59fb0-ef68-11ee-8969-d79e651c4a6d
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_9339_66096f5baa474.jpeg
# sending data/avalanche_center/webscrape/Images/608e8afe-5258-48d9-8edd-2e5732dde9b2-c3d59fb0-ef68-11ee-8969-d79e651c4a6d.jpg
# MediaType = image
# ***************************************************
# Media Id = 608e8afe-5258-48d9-8edd-2e5732dde9b2-c45a3798-ef68-11ee-aa1d-d7cd29bb93e7
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_9337_66096f5c21b59.jpeg
# sending data/avalanche_center/webscrape/Images/608e8afe-5258-48d9-8edd-2e5732dde9b2-c45a3798-ef68-11ee-aa1d-d7cd29bb93e7.jpg
# MediaType = image
# ***************************************************
# Media Id = 608e8afe-5258-48d9-8edd-2e5732dde9b2-c511fdc4-ef68-11ee-89e4-eb2422c83af0
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_9332_66096f5cb2e05.jpeg
# sending data/avalanche_center/webscrape/Images/608e8afe-5258-48d9-8edd-2e5732dde9b2-c511fdc4-ef68-11ee-89e4-eb2422c83af0.jpg
# MediaType = image
# ***************************************************
# Media Id = 608e8afe-5258-48d9-8edd-2e5732dde9b2-c516847a-ef68-11ee-a9ba-930eb80f6ff8
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_9333_66096f5d51674.jpeg
# sending data/avalanche_center/webscrape/Images/608e8afe-5258-48d9-8edd-2e5732dde9b2-c516847a-ef68-11ee-a9ba-930eb80f6ff8.jpg
# MediaType = image
# ***************************************************
# Media Id = c94c2f88-4255-458f-9f75-6837f00c8a04-78c473da-efc1-11ee-a4d5-037d6fa5f4c1
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1952_660a043557568.jpg
# sending data/avalanche_center/webscrape/Images/c94c2f88-4255-458f-9f75-6837f00c8a04-78c473da-efc1-11ee-a4d5-037d6fa5f4c1.jpg
# MediaType = image
# ***************************************************
# Media Id = c94c2f88-4255-458f-9f75-6837f00c8a04-79e70d04-efc1-11ee-8496-c79be5a847fc
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_1953_660a0437081be.jpg
# sending data/avalanche_center/webscrape/Images/c94c2f88-4255-458f-9f75-6837f00c8a04-79e70d04-efc1-11ee-8496-c79be5a847fc.jpg
# MediaType = image
# ***************************************************
# Media Id = 7d908847-63b7-4d28-adcf-4767e951bbc4-8209263c-efc3-11ee-b7d3-c382cb449dfb
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/image000001_660a07a28732d.jpeg
# sending data/avalanche_center/webscrape/Images/7d908847-63b7-4d28-adcf-4767e951bbc4-8209263c-efc3-11ee-b7d3-c382cb449dfb.jpg
# MediaType = image
# ***************************************************
# Media Id = 7d908847-63b7-4d28-adcf-4767e951bbc4-82bb5636-efc3-11ee-888f-938e367cf9b3
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/image000000_660a07a374670.jpeg
# sending data/avalanche_center/webscrape/Images/7d908847-63b7-4d28-adcf-4767e951bbc4-82bb5636-efc3-11ee-888f-938e367cf9b3.jpg
# MediaType = image
# ***************************************************
# Media Id = 7d908847-63b7-4d28-adcf-4767e951bbc4-841bb03e-efc3-11ee-8a6f-c3cddd748406
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_0917_660a07a458637.jpeg
# sending data/avalanche_center/webscrape/Images/7d908847-63b7-4d28-adcf-4767e951bbc4-841bb03e-efc3-11ee-8a6f-c3cddd748406.jpg
# MediaType = image
# ***************************************************
# Media Id = aafa7d85-0aff-44c7-a847-47bceb54e9ce-bca5be48-ef5c-11ee-ac9a-13d20e16ad2f
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_4108_66095b300f2d0.jpeg
# sending data/avalanche_center/webscrape/Images/aafa7d85-0aff-44c7-a847-47bceb54e9ce-bca5be48-ef5c-11ee-ac9a-13d20e16ad2f.jpg
# MediaType = image
# ***************************************************
# Media Id = aafa7d85-0aff-44c7-a847-47bceb54e9ce-bce0caba-ef5c-11ee-9c78-67020cc25c48
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_4105_66095b303b7bf.jpeg
# sending data/avalanche_center/webscrape/Images/aafa7d85-0aff-44c7-a847-47bceb54e9ce-bce0caba-ef5c-11ee-9c78-67020cc25c48.jpg
# MediaType = image
# ***************************************************
# Media Id = aafa7d85-0aff-44c7-a847-47bceb54e9ce-bd13251e-ef5c-11ee-b3df-5763e0376ddf
# sending image https://avalanche-org-media.s3.us-west-2.amazonaws.com/IMG_4110_66095b304e9f7.jpeg
# sending data/avalanche_center/webscrape/Images/aafa7d85-0aff-44c7-a847-47bceb54e9ce-bd13251e-ef5c-11ee-b3df-5763e0376ddf.jpg
