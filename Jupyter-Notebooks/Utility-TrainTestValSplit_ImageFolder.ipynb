# %% [markdown]
# ## Helper code to do test/train/val split
#
# images are originally stored in S3 at s3://s3-avalanche-guard/data/cv/uibk/ResNetClassify/train
#
# After running the following code, we will move a percentage to s3://s3-avalanche-guard/data/cv/uibk/ResNetClassify/val
#
#
# To access S3 or any other AWS services we need SDK
# The SDK is composed of two key Python packages: Botocore (the library providing the low-level functionality shared between the Python SDK and the AWS CLI) and Boto3 (the package implementing the Python SDK itself).

# %%
import boto3
import random
import shutil

# %%
# move an S3 object to another object
# example:
#move_s3_object('my_bucket', old_key='tmp/test.txt', new_key='tmp/tmp2/test.txt')
def move_s3_object(bucket: str, old_key: str, new_key: str) -> None:
    boto3.resource('s3').Object(bucket,  new_key).copy_from(CopySource=f'{bucket}/{old_key}')
    boto3.client('s3').delete_object(Bucket=bucket, Key=old_key)

# move an S3 object to another folder
# example:
#move_s3_object('my_bucket', old_folder='tmp/', new_folder='tmp/tmp2/', object_name='test.txt')
def s3_move_to_another_folder(bucket: str, old_folder: str, new_folder: str, object_name:str, deletesource:bool=True) -> None:
    
    old_key = old_folder+object_name
    new_key = new_folder+object_name
    boto3.resource('s3').Object(bucket,  new_key).copy_from(CopySource=f'{bucket}/{old_key}')
    if deletesource:
        boto3.client('s3').delete_object(Bucket=bucket, Key=old_key)

    

#print bucket contents
def print_all_s3_objects(bucket_name:str, prefix:str, replaceLine : bool = True):
    s3 = boto3.client('s3')
    paginator = s3.get_paginator('list_objects_v2')
    page_iterator = paginator.paginate(Bucket=bucket_name,Prefix=prefix)
    i=0

    for page in page_iterator:
        if 'Contents' in page:
            for obj in page['Contents']:
                i=i+1
                if replaceLine:
                    print(f'**** Count={i}, Name: {obj["Key"]} |                                                    Size: {obj["Size"]}', end="\r")
                else:
                    print(f'**** Count={i}, Name: {obj["Key"]} |                                                    Size: {obj["Size"]}')
        else:
            print("Bucket is empty or does not exist")


# Get bucket contents as a list
def list_all_s3_objects(bucket_name:str, prefix:str)-> [str]:
    s3 = boto3.client('s3')
    paginator = s3.get_paginator('list_objects_v2')
    page_iterator = paginator.paginate(Bucket=bucket_name,Prefix=prefix)

    objlist = []
    for page in page_iterator:
        if 'Contents' in page:
            for obj in page['Contents']:
                objlist.append( obj["Key"].replace(prefix, ""))

    return objlist
            
            
def split_train_val(s3_bucket_name:str, source_folder_name:str, train_val_testfolders:[str], 
                    train_val_test_pct:[float],test_mode:bool=False):

    # Create a list of image filenames in 'data_path'
    imgs_list = list_all_s3_objects(s3_bucket_name,source_folder_name)

    # Sets the random seed 
    random.seed(42)

    # Shuffle the list of image filenames
    random.shuffle(imgs_list)
    
    # get the split pct
    if len(train_val_test_pct) == 1:
        train_pct = train_val_test_pct[0]
        test_pct=0
        val_pct = 0
    elif len(train_val_test_pct) == 2:
        train_pct = train_val_test_pct[0]
        val_pct = train_val_test_pct[1]
        test_pct= 0
    elif len(train_val_test_pct) == 3:
        train_pct = train_val_test_pct[0]
        val_pct = train_val_test_pct[1]         
        test_pct=train_val_test_pct[2]
        
    else:
        raise("Error")

        
    # get the folders    
    if len(train_val_testfolders) == 1:
        train_folder = train_val_testfolders[0]
        test_folder="none"
        val_folder = "none"
        
    elif len(train_val_testfolders) == 2:
        train_folder = train_val_testfolders[0]
        val_folder = train_val_testfolders[1]
        test_folder= "none"

    elif len(train_val_testfolders) == 3:
        train_folder = train_val_testfolders[0]
        val_folder = train_val_testfolders[1]         
        test_folder=train_val_testfolders[2]

    else:
        raise("Error")
        

    # determine the number of images for each set
    train_size = int(len(imgs_list) * train_pct)
    val_size = int(len(imgs_list) * val_pct)
    test_size = int(len(imgs_list) * test_pct)

    # Create destination folders if they don't exist
    # ** to do ** 

    # Copy image files to destination folders
    for i, f in enumerate(imgs_list):
        if i < train_size:
            dest_folder = train_folder
        elif i < train_size + val_size:
            dest_folder = val_folder
        else:
            dest_folder = test_folder
        if test_mode:
            print("planning to move {0} from {1} to {2}".format(f,source_folder_name, dest_folder))
        else:
            print("moving {0} from {1}   to    {2}          ".format(f,source_folder_name, dest_folder) , end = "\r"  )
            s3_move_to_another_folder(s3_bucket_name, old_folder=source_folder_name, 
                                  new_folder=dest_folder, 
                                  object_name=f)
            print("done")

# %%
## Prepare data for Experiment 2 - Avalanche or Not

s3_bucket_name = "s3-avalanche-guard"
src_folder = "data/cv/uibk/images/none/"
new_folder = "data/experiments/exp02-binary-avalanche/orig/negative/"
src_prefix = "data/cv/uibk/images/none/"


img_list = list_all_s3_objects(s3_bucket_name, src_prefix)

for idx, object_name in enumerate(img_list):
    print(f"now moving {idx}   image",end='\r')
    s3_move_to_another_folder(s3_bucket_name, src_folder, new_folder, object_name, deletesource=False)
# Out:
# now moving 1070   image

# %%
s3_bucket_name = "s3-avalanche-guard"

##source_folder = "data/cv/uibk/ResNetClassify/train/"
##dest_folder = "data/cv/uibk/ResNetClassify/val/"


###print_all_s3_objects(s3_bucket_name,"data/experiments/exp01-terrain-binary/positive/")
print("")
print("")

###print_all_s3_objects(s3_bucket_name,"data/experiments/exp01-terrain-binary/negative/")

SKIP = False
print("")
print(SKIP)
if SKIP :
    print('Skipping the train/val split step')
    pass
else:
    split_train_val(s3_bucket_name,
                "data/experiments/exp02-binary-avalanche/orig/negative/",
                [
                    "data/experiments/exp02-binary-avalanche/train/negative/",
                    "data/experiments/exp02-binary-avalanche/val/negative/",
                    "data/experiments/exp02-binary-avalanche/test/negative/"
                ],
                [.70,.20,.10],)
# Out:
# False
# doneng 2015-03-31 karnischer kamm (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-01-22 hohe geige (9).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-01-30 hochgurgl (14).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-02-23 jamtal (12).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-03-06 rietzer grieskogel (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-03-19 jamtalhuette (10).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-01-16 kaunertal (19).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-12-26 obergurgel (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-12-15 jaufental (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-02-13 jaegerscharte (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-12-26 oestliche tuxer alpen (93).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-03-16 vorderer seelenkogel (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-02-28 wipptal (15).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-01-05 nauders (9).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-01-13 gilfert (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-02-23 jamtal (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-02-12 kuehtai (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-03-21 knotenspitze (18).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-04-30 schalfkogel (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-02-03 kinigat (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-11-20 obergurgl (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-03-22 puerglers kunke (11).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-04-11 haiderspitze (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-01-16 oberland (147).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-01-31 neunerkogel (13).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-02-06 geier (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-01-16 schlick (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-11-30 obergurgl (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-02-06 kahorn (18).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-02-20 grosser galtenberg (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-03-04 sellrain (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-01-10 osttirol (69).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-03-08 kraeulscharte (19).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-02-19 noerdl.lechtaler alpen (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-02-08 jamtal (62).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-01-30 ampferstein (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-03-04 stubaier gletscher (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-03-23 neuburgalm (57).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-03-29 laengentaler weisserkogel (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-02-13 rosskogel (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-03-24 leobner (57).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-01-11 noerdliche oetztaler- und stubaier alpen (11).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-04-21 zwieselbacher rosskogel (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-03-22 kreuzspitze (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-12-11 osttirol (38).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-01-02 niedererberg (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-12-10 kuehtai (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-03-12 muttenkof (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-02-06 sellrain (10).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-01-06 pfoner kreuzjoechl (8).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-03-23 zoachen (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-04-14 kuehtai (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-12-20 grieser griesskogel (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-04-18 osttirol (77).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-12-16 osttirol (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-01-11 wilder kaiser (108).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-02-03 nordkette (46).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-01-28 hornkoepfl (17).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-12-19 mitterkopf (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-02-28 serles (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-01-19 kreuzriedel (17).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-04-28 westliche schwarzenbergspitze (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-04-07 langtaufers (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-02-28 kesselspitze (8).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-03-17 landeggtal (38).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-01-01 kuehtai (9).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-01-19 tirol (140).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-01-02 zeiritz (57).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-01-23 hillary kreuz (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-04-19 xeis (57).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-03-04 stubaier gletscher (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-02-13 breiter griesskogel (15).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-04-02 obergurgl (8).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-01-02 steintalspitze (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-02-16 patscherkofel (12).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-03-28 venedigergruppe (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-04-20 aeussere kraeulscharte (38).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-12-12 kreuzjoch (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-04-05 zischgeles (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-01-11 koefels (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-02-04 matrei i. o. (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-01-24 berger kogel (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-04-13 wipp- und gschnitztal (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-02-06 hohe koepfe (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-01-19 tuxerjochhaus (8).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-03-10 mugkogel (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-02-06 obergurgl (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-04-20 eisenerzer alpen (17).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-04-10 simonyspitze (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-11-28 stubaier gletscher (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-02-28 trunaalm (12).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-03-22 obergurgl (7).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-02-18 kreuzeckgruppe (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-03-25 navistal (7).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-04-02 obergurgl (11).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-04-14 praegraten (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-01-20 wanglspitze (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-01-04 kaunertal (58).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-01-23 hillary kreuz (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-04-20 franzsennhuette (57).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-03-13 olperer (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-03-09 schafgruebler (25).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-04-20 aeussere kraeulscharte (64).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-04-24 kuehtai (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-02-11 wankspitze (36).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-02-13 rosskogel (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-12-13 wildkogel salzburg (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-04-18 osttirol (132).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-04-30 luesener spitze (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-02-04 wilder freiger (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-03-22 kreuzspitze (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-04-25 wilder freiger (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-01-11 kaunertal (14).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-02-10 obertilliach (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-12-13 innerberger-felderkogel (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-01-24 westtirol (123).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-01-15 kurzras (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-01-19 schafboedenalm (17).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-12-25 tuxer und zillertaler hauptkamm (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-12-18 predigberg (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-04-06 kleiner kaserer (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-01-19 oberndorf (57).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-01-18 kitzbuehel (57).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-03-19 koflerspitzen (7).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-03-05 nockspitze (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-03-06 grinbgerspitze (84).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-04-28 franz-senn-huette (95).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-11-14 zentralosttirol (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-01-06 wald im pitztal (8).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-04-13 oestliche seespitze (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-03-08 innsbruck (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-02-28 winnebacher weisserkogel (9).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-01-15 kreuzspitze villgratental (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-02-22 tauernhauptkamm (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-04-13 wipp- und gschnitztal (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-01-01 ox grat (17).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-02-28 cima (13).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-04-03 wattener lizum (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-01-24 westtirol (63).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-02-07 seespitze (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-01-27 obergurgl (16).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-12-26 oetztal (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-12-31 zwieseslbacher rosskogel (84).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-01-10 osttirol (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-01-02 roethenspitze (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-01-07 axamer lizum (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-03-14 fernerkogel (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-02-11 schoental (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-01-06 pfoner kreuzjoechl (7).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-01-18 nauders-valdafour (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-03-24 hoher lorenzen (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-04-18 osttirol (162).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-03-06 grieskogel (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-01-10 messelingkogel (9).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-02-28 wipptal (17).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-03-09 ampferstein (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-12-25 tuxer und zillertaler hauptkamm (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-02-23 westtirol (41).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-03-08 kraeulscharte (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-01-30 tuxer alpen (25).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-11-10 suedliches osttirol (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-12-07 tirol (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-01-30 juifenalm (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-03-09 leutascher dreitorspitze (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-12-11 osttirol (33).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-01-06 hochgasser (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-04-28 franz-senn-huette (87).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-03-03 thaurerjochspitze (84).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-01-06 niedererberg (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-03-20 kalkkoegel (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-04-20 stadelstein (17).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-01-26 widdersberg (44).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-01-24 westtirol (178).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-03-08 luesens (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-05-07 kuehtai (57).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-04-03 lampsenspitze (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-01-14 nordkette-schneekar (10).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-01-09 stubaier gletscher (7).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-12-24 gscheideggkogel (57).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-11-30 hohe koepfe (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-01-19 koegele (9).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-02-25 schafkar (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-01-19 rietzer grieskogel (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-02-12 karnischer kamm (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-01-07 pfoner kreuzjoechl (98).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-01-30 juifenalm (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-12-11 hoher seeblaskogel (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-01-26 lkk hochfilzen (7).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-01-23 hillary kreuz (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-01-22 henne (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-01-09 brenta (60).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-04-21 kaunertal (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-02-09 reither spitze (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-02-23 westtirol (58).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-02-03 kinigat (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-01-05 nauders (7).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-01-18 westendorf (57).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-02-14 kalkstein (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-01-11 wilder kaiser (92).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-03-15 jamtal (68).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-03-11 wolfendorn (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-01-18 kaltenbach-hochfuegen (34).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-01-30 kalkkoegel (57).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-02-13 rotmoostal (9).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-02-08 jamtal (129).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-03-11 sellrain-haggen-steintalpitze (8).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-02-10 wildangerspitze (8).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-02-14 kalkstein (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-04-18 osttirol (141).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-01-06 noesslach (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-03-08 kraeulscharte (22).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-11-26 stubai-oetztal (34).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-02-26 stubaier gletscher (67).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-02-11 rietzer griesskogel (7).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-02-04 wilder freiger (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-01-24 sellraintal (40).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-12-30 groeger sattel (17).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-12-29 fotscher windegg (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-04-03 wattener lizum (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-02-04 glorerhuette (13).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-04-02 osttiroler tauern (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-11-08 grossvenediger (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-01-01 kuehtai (7).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-04-19 zwieselbacher rosskogel (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-04-30 schalfkogel (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-04-18 osttirol (49).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-02-13 suedliches osttirol (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-01-30 kitzbuehler alpen (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-01-19 tirol (185).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-03-09 franz-senn-huette (64).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-02-24 rote wand (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-04-02 kalbenjoch (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-02-09 pitztaler gletscher - taschachtal (19).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-03-23 osttiroler tauern (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-12-02 stubaier gletscher (11).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-03-13 kuhscheibe (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-01-02 obernbergtal (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-02-10 wildangerspitze (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-02-09 wildangerspitze (39).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-03-08 kraeulscharte (29).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-03-20 schnapfenspitze (19).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-12-26 mitterzeiger, kuehtai (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-02-13 schleinitz (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-04-18 osttirol (83).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-12-07 tirol (19).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-03-11 wolfendorn (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-03-31 seekar (17).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-01-16 kaisergebirge (42).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2021-03-26 hoelltalspitze (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-02-10 gruberscharte (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-02-10 wildangerspitze (12).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-01-01 luesener fernerkogel (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-01-24 lampsenspitze (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-02-22 jamtal (40).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-01-29 lamsenspitze (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-02-11 villgratental (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-04-02 torwand (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-04-14 hoher boesring (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-12-23 kraspestal (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-11-07 tuxer und zillertaler alpen (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-12-28 schoentalspitze (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-04-14 wattener lizum (18).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2022-01-02 leitnerberg (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-12-22 obergurgl (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2015-01-28 kleiner gilfert (23).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-12-11 osttirol (141).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-11-14 obergurgl und hochgurgl (23).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-12-24 niltal (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-01-15 schoberspitze (17).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2019-02-06 westtirol (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2017-02-13 rietzer grieskogel - rangger koepfl (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2016-01-27 tuxer alpen (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-12-20 rosengarten (84).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2018-03-25 navistal (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# doneng 2020-02-17 jamtal (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/train/negative/
# ...
# doneng 2017-02-07 galtuer (14).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2015-02-04 glorerhuette (21).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2021-01-16 lampsenspitze (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2021-01-15 gurgler gruppe (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2021-02-23 westtirol (59).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2017-12-13 peider sonnberg (7).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2020-01-30 ampferstein (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2017-01-19 rietzer grieskogel (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2019-03-09 villgratental (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2022-04-18 osttirol (159).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2019-12-26 nordkette (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2022-01-29 hillary kreuz (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2017-03-07 oefenspitze (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2018-01-24 westtirol (74).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2018-04-02 osttiroler tauern (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2016-03-06 ranalt-roetenspitze (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2017-02-13 rotmoostal (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2020-12-10 st. jakob i. d. (8).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2019-01-16 westliches nordtirol (50).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2016-03-09 franz-senn-huette (63).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2022-03-27 rote wand (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2019-05-17 finstertal-kraspestal (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2015-02-28 hintere karlesspitze (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2019-12-28 schoentalspitze (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2020-01-27 obergurgl (8).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2022-02-09 tirol (39).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2020-02-08 staller sattel (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2017-02-27 bielerhoehe - bielerspitze (14).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2020-01-14 grosser geiger (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2016-04-28 zischgeles (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2018-01-13 arlberg - knoedel (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2018-01-24 westtirol (163).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2016-03-05 glungezer (14).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2018-01-22 defereggen (16).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2021-02-17 soelden (97).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2019-12-15 praxmarer griesskogel (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2018-03-25 venedigergruppe (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2017-03-21 nauders (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2018-01-25 westtirol (10).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2015-12-02 stubaier gletscher (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2021-03-25 oberland (8).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2017-02-07 naviser wetterkreuz (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2021-03-19 obergurgl (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2016-02-24 pfannknechtscharte (7).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2019-03-24 leobner flaeche (17).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2018-04-02 obergurgl (10).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2015-04-03 lampsenspitze (7).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2016-02-06 geier (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2018-02-04 gr. kinigat (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2020-03-04 zwieselbacher rosskogel (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2019-03-31 pflerscher pinggl (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2016-02-24 breiter grieskogel (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2021-01-05 seespitzl (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2017-02-16 venedigergruppe (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2022-01-23 hillary kreuz (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2015-03-08 stempeljoch reibn (12).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2019-01-15 nordektte (13).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2020-01-30 kitzbuehler alpen (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2020-02-27 alpenhauptkamm (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2016-03-27 rosshuette (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2021-01-06 puergler kunke (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2016-03-18 lienzer dolomiten (16).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2022-04-18 osttirol (88).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2020-01-19 rietzer grieskogel (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2018-03-11 sellrain-haggen-steintalpitze (9).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2017-11-09 grossglockner (7).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2022-04-18 osttirol (46).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2020-01-27 obergurgl (15).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2021-02-23 westtirol (62).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2017-12-07 soelden (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2015-01-05 obergurgl (15).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2019-03-09 villgratental (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2022-01-06 obernbergtal (6).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2018-03-22 kreuzspitze (8).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2021-02-23 westtirol (35).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2018-02-13 schleinitz (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2015-02-03 zettersfeld (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2022-04-18 osttirol (140).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2018-04-02 telfs (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2018-03-18 hinterbergkofel (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2016-03-19 glungezer (5).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2015-02-07 pleiskopf (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2015-02-07 stiergschwez (3).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2021-02-23 westtirol (60).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2016-03-09 westliche dremelscharte (4).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2016-04-28 franz-senn-huette (46).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2017-03-24 seelenkogel (2).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2018-03-22 puerglers kunke (24).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2018-12-12 wanglspitze (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2019-02-15 silvretta (34).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2015-02-03 marchkinkele (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
# doneng 2017-01-22 henne (1).jpg from data/experiments/exp02-binary-avalanche/orig/negative/   to    data/experiments/exp02-binary-avalanche/test/negative/
